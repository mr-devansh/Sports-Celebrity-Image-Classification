# %%
import numpy as np
import cv2
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./IMAGES/ROHIT SHARMA/007.jpg')
img.shape
# Out:
# (1080, 1440, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1080, 1440)

# %%
plt.imshow(gray, cmap='gray')

# %%
#we use HAAR cascasde in openCV for face recogniction that uses moving window to detect face features like eyes nose ears and lips
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[557, 402, 250, 250]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (557, 402, 250, 250)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (250, 250, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./IMAGES/ROHIT SHARMA/007.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./IMAGES/ROHIT SHARMA/007.jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "./IMAGES/"
path_to_cr_data = "./IMAGES/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./IMAGES/cropped',
#  './IMAGES/HARDIK PANDIYA',
#  './IMAGES/ROHIT SHARMA',
#  './IMAGES/VIRAT KHOLI']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./IMAGES/cropped/HARDIK PANDIYA
# Generating cropped images in folder:  ./IMAGES/cropped/ROHIT SHARMA
# Generating cropped images in folder:  ./IMAGES/cropped/VIRAT KHOLI

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'HARDIK PANDIYA': ['./IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA1.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA10.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA11.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA12.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA13.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA14.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA15.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA16.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA17.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA18.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA19.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA2.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA20.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA21.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA22.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA23.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA24.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA25.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA26.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA27.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA28.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA29.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA3.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA30.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA31.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA32.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA33.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA34.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA35.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA36.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA37.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA38.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA39.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA4.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA40.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA41.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA42.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA43.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA44.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA45.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA46.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA47.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA48.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA49.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA5.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA50.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA51.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA52.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA53.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA54.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA55.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA56.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA57.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA58.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA59.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA6.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA60.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA61.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA62.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA63.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA64.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA65.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA66.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA67.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA68.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA69.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA7.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA70.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA71.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA72.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA73.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA74.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA75.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA76.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA77.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA78.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA79.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA8.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA80.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA81.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA82.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA83.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA84.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA85.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA86.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA87.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA88.png',
#   './IMAGES/cropped/HARDIK PANDIYA\\HARDIK PANDIYA9.png'],
#  'ROHIT SHARMA': ['./IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA1.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA10.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA11.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA12.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA13.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA14.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA15.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA16.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA17.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA18.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA19.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA2.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA20.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA21.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA22.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA23.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA24.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA25.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA26.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA27.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA28.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA29.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA3.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA30.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA31.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA32.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA33.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA34.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA35.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA36.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA37.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA38.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA39.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA4.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA40.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA41.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA42.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA43.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA44.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA45.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA46.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA47.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA48.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA49.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA5.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA50.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA51.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA52.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA53.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA54.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA55.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA56.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA57.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA58.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA59.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA6.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA60.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA61.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA62.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA63.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA64.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA65.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA66.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA67.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA68.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA69.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA7.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA70.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA71.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA72.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA73.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA74.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA75.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA76.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA77.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA78.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA79.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA8.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA80.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA81.png',
#   './IMAGES/cropped/ROHIT SHARMA\\ROHIT SHARMA9.png'],
#  'VIRAT KHOLI': ['./IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI1.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI10.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI11.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI12.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI13.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI14.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI15.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI16.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI17.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI18.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI19.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI2.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI20.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI21.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI22.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI23.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI24.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI25.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI26.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI27.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI28.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI29.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI3.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI30.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI31.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI32.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI33.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI34.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI35.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI36.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI37.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI38.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI39.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI4.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI40.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI41.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI42.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI43.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI44.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI45.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI46.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI47.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI48.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI49.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI5.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI50.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI51.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI52.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI53.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI54.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI55.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI56.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI57.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI58.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI59.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI6.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI60.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI61.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI62.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI63.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI64.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI65.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI66.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI67.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI68.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI69.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI7.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI70.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI71.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI72.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI73.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI74.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI75.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI76.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI77.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI78.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI79.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI8.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI80.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI81.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI82.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI83.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI84.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI85.png',
#   './IMAGES/cropped/VIRAT KHOLI\\VIRAT KHOLI9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'HARDIK PANDIYA': 0, 'ROHIT SHARMA': 1, 'VIRAT KHOLI': 2}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 24],
#        [ 25],
#        [ 29],
#        ...,
#        [198],
#        [ 23],
#        [ 59]], dtype=uint8)

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (254, 4096)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.71875

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73        19
#            1       0.71      0.74      0.72        23
#            2       0.78      0.64      0.70        22
#
#     accuracy                           0.72        64
#    macro avg       0.72      0.72      0.72        64
# weighted avg       0.72      0.72      0.72        64

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.768421
# 1        random_forest    0.547368
# 2  logistic_regression    0.773684
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
print(best_estimators['svm'].score(X_test,y_test))
print(best_estimators['random_forest'].score(X_test,y_test))
print(best_estimators['logistic_regression'].score(X_test,y_test))
# Out:
# 0.703125
# 0.578125
# 0.71875

# %%
best_clf = best_estimators['logistic_regression']

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm

import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
# !pip install joblib
import pickle 
with open('saved_model.pkl', 'wb') as file:
    pickle.dump(best_clf, file)
# Out:
# Requirement already satisfied: joblib in c:\users\devansh singh\anaconda3\lib\site-packages (1.2.0)

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
